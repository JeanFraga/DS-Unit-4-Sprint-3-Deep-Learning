# %% [markdown]
# <img align="left" src="https://lever-client-logos.s3.amazonaws.com/864372b1-534c-480e-acd5-9711f850815c-1524247202159.png" width=200>
# <br></br>
# <br></br>
#
# ## *Data Science Unit 4 Sprint 3 Lesson 1*
#
# # Recurrent Neural Networks and Long Short Term Memory (LSTM)
# ## _aka_ PREDICTING THE FUTURE!
#
# <img src="https://media.giphy.com/media/l2JJu8U8SoHhQEnoQ/giphy.gif" width=480 height=356>
# <br></br>
# <br></br>
#
# > "Yesterday's just a memory - tomorrow is never what it's supposed to be." -- Bob Dylan
#
# Wish you could save [Time In A Bottle](https://www.youtube.com/watch?v=AnWWj6xOleY)? With statistics you can do the next best thing - understand how data varies over time (or any sequential order), and use the order/time dimension predictively.
#
# A sequence is just any enumerated collection - order counts, and repetition is allowed. Python lists are a good elemental example - `[1, 2, 2, -1]` is a valid list, and is different from `[1, 2, -1, 2]`. The data structures we tend to use (e.g. NumPy arrays) are often built on this fundamental structure.
#
# A time series is data where you have not just the order but some actual continuous marker for where they lie "in time" - this could be a date, a timestamp, [Unix time](https://en.wikipedia.org/wiki/Unix_time), or something else. All time series are also sequences, and for some techniques you may just consider their order and not "how far apart" the entries are (if you have particularly consistent data collected at regular intervals it may not matter).

# %% [markdown]
# ## Recurrent Neural Networks
#
# There's plenty more to "traditional" time series, but the latest and greatest technique for sequence data is recurrent neural networks. A recurrence relation in math is an equation that uses recursion to define a sequence - a famous example is the Fibonacci numbers:
#
# $F_n = F_{n-1} + F_{n-2}$
#
# For formal math you also need a base case $F_0=1, F_1=1$, and then the rest builds from there. But for neural networks what we're really talking about are loops:
#
# ![Recurrent neural network](https://upload.wikimedia.org/wikipedia/commons/b/b5/Recurrent_neural_network_unfold.svg)
#
# The hidden layers have edges (output) going back to their own input - this loop means that for any time `t` the training is at least partly based on the output from time `t-1`. The entire network is being represented on the left, and you can unfold the network explicitly to see how it behaves at any given `t`.
#
# Different units can have this "loop", but a particularly successful one is the long short-term memory unit (LSTM):
#
# ![Long short-term memory unit](https://upload.wikimedia.org/wikipedia/commons/thumb/6/63/Long_Short-Term_Memory.svg/1024px-Long_Short-Term_Memory.svg.png)
#
# There's a lot going on here - in a nutshell, the calculus still works out and backpropagation can still be implemented. The advantage (ane namesake) of LSTM is that it can generally put more weight on recent (short-term) events while not completely losing older (long-term) information.
#
# After enough iterations, a typical neural network will start calculating prior gradients that are so small they effectively become zero - this is the [vanishing gradient problem](https://en.wikipedia.org/wiki/Vanishing_gradient_problem), and is what RNN with LSTM addresses. Pay special attention to the $c_t$ parameters and how they pass through the unit to get an intuition for how this problem is solved.
#
# So why are these cool? One particularly compelling application is actually not time series but language modeling - language is inherently ordered data (letters/words go one after another, and the order *matters*). [The Unreasonable Effectiveness of Recurrent Neural Networks](https://karpathy.github.io/2015/05/21/rnn-effectiveness/) is a famous and worth reading blog post on this topic.
#
# For our purposes, let's use TensorFlow and Keras to train RNNs with natural language. Resources:
#
# - https://github.com/keras-team/keras/blob/master/examples/imdb_lstm.py
# - https://keras.io/layers/recurrent/#lstm
# - http://adventuresinmachinelearning.com/keras-lstm-tutorial/
#
# Note that `tensorflow.contrib` [also has an implementation of RNN/LSTM](https://www.tensorflow.org/tutorials/sequences/recurrent).

# %% [markdown]
# ### RNN/LSTM Sentiment Classification with Keras

# %%
'''
#Trains an LSTM model on the IMDB sentiment classification task.
The dataset is actually too small for LSTM to be of any advantage
compared to simpler, much faster methods such as TF-IDF + LogReg.
**Notes**
- RNNs are tricky. Choice of batch size is important,
choice of loss and optimizer is critical, etc.
Some configurations won't converge.
- LSTM loss decrease patterns during training can be quite different
from what you see with CNNs/MLPs/etc.
'''
from __future__ import print_function

from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding
from tensorflow.keras.layers import LSTM
from tensorflow.keras.datasets import imdb

max_features = 20000
# cut texts after this number of words (among top max_features most common words)
maxlen = 80
batch_size = 32

print('Loading data...')
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')
# Out:
# Loading data...
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 8s 0us/step
# 25000 train sequences
# 25000 test sequences

# %%
len(x_train)
# Out:
# 25000

# %%
print('Pad sequences (samples x time)')
x_train = sequence.pad_sequences(x_train, maxlen=maxlen)
x_test = sequence.pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# Pad sequences (samples x time)
# x_train shape: (25000, 80)
# x_test shape: (25000, 80)

# %%
x_train[0]
# Out:
# array([   15,   256,     4,     2,     7,  3766,     5,   723,    36,
#           71,    43,   530,   476,    26,   400,   317,    46,     7,
#            4, 12118,  1029,    13,   104,    88,     4,   381,    15,
#          297,    98,    32,  2071,    56,    26,   141,     6,   194,
#         7486,    18,     4,   226,    22,    21,   134,   476,    26,
#          480,     5,   144,    30,  5535,    18,    51,    36,    28,
#          224,    92,    25,   104,     4,   226,    65,    16,    38,
#         1334,    88,    12,    16,   283,     5,    16,  4472,   113,
#          103,    32,    15,    16,  5345,    19,   178,    32])

# %%
print('Build model...')
model = Sequential()
model.add(Embedding(max_features, 128))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

# try using different optimizers and different optimizer configs
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print('Train...')
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=15,
          validation_data=(x_test, y_test))
score, acc = model.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Build model...
# Train...
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/15
# 25000/25000 [==============================] - 100s 4ms/sample - loss: 0.4610 - accuracy: 0.7824 - val_loss: 0.3991 - val_accuracy: 0.8220
# Epoch 2/15
# 25000/25000 [==============================] - 100s 4ms/sample - loss: 0.3002 - accuracy: 0.8775 - val_loss: 0.3981 - val_accuracy: 0.8360
# Epoch 3/15
# 25000/25000 [==============================] - 100s 4ms/sample - loss: 0.2188 - accuracy: 0.9160 - val_loss: 0.4459 - val_accuracy: 0.8102
# Epoch 4/15
# 25000/25000 [==============================] - 98s 4ms/sample - loss: 0.1543 - accuracy: 0.9422 - val_loss: 0.4674 - val_accuracy: 0.8286
# Epoch 5/15
# 25000/25000 [==============================] - 98s 4ms/sample - loss: 0.1110 - accuracy: 0.9597 - val_loss: 0.5098 - val_accuracy: 0.8246
# Epoch 6/15
# 25000/25000 [==============================] - 99s 4ms/sample - loss: 0.0868 - accuracy: 0.9701 - val_loss: 0.6992 - val_accuracy: 0.8167
# Epoch 7/15
# 25000/25000 [==============================] - 98s 4ms/sample - loss: 0.0614 - accuracy: 0.9792 - val_loss: 0.6882 - val_accuracy: 0.8146
# Epoch 8/15
# 25000/25000 [==============================] - 98s 4ms/sample - loss: 0.0514 - accuracy: 0.9837 - val_loss: 0.7055 - val_accuracy: 0.8142
# Epoch 9/15
# 25000/25000 [==============================] - 100s 4ms/sample - loss: 0.0397 - accuracy: 0.9865 - val_loss: 0.7514 - val_accuracy: 0.8119
# Epoch 10/15
# 25000/25000 [==============================] - 99s 4ms/sample - loss: 0.0281 - accuracy: 0.9915 - val_loss: 0.8307 - val_accuracy: 0.8154
# Epoch 11/15
# 25000/25000 [==============================] - 103s 4ms/sample - loss: 0.0192 - accuracy: 0.9941 - val_loss: 0.9405 - val_accuracy: 0.8133
# Epoch 12/15
# 25000/25000 [==============================] - 99s 4ms/sample - loss: 0.0191 - accuracy: 0.9942 - val_loss: 1.0118 - val_accuracy: 0.8067
# Epoch 13/15
# 25000/25000 [==============================] - 100s 4ms/sample - loss: 0.0127 - accuracy: 0.9960 - val_loss: 1.1036 - val_accuracy: 0.8108
# Epoch 14/15
# 25000/25000 [==============================] - 103s 4ms/sample - loss: 0.0158 - accuracy: 0.9950 - val_loss: 1.1126 - val_accuracy: 0.8094
# Epoch 15/15
# 25000/25000 [==============================] - 100s 4ms/sample - loss: 0.0106 - accuracy: 0.9968 - val_loss: 1.0984 - val_accuracy: 0.8106
# 25000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# Test score: 1.0983743128657342
# Test accuracy: 0.81056

# %% [markdown]
# ### LSTM Text generation with Keras
#
# What else can we do with LSTMs? Since we're analyzing the *sequence*, we can do more than classify - we can *generate* text. I'ved pulled some news stories using [newspaper](https://github.com/codelucas/newspaper/).
#
# This example is drawn from the Keras [documentation](https://keras.io/examples/lstm_text_generation/).

# %%
from tensorflow.keras.callbacks import LambdaCallback
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM
from tensorflow.keras.optimizers import RMSprop

import numpy as np
import random
import sys
import os

# %%
data_files = os.listdir('./articles')

# %%
# Read in Data

data = []

for file in data_files:
    if file[-3:] == 'txt':
        with open(f'./articles/{file}', 'r', encoding="utf8") as f:
            data.append(f.read())

# %%
len(data)
# Out:
# 136

# %%
data[0]
# Out:
# 'A white Fort Worth police officer fatally shot a black woman in her home early Saturday, firing through a bedroom window while responding to a call about an open door at the residence, police said.\n\nOfficers were dispatched to the house in the city’s Hillside Morningside neighborhood at 2:25 a.m. after receiving an “open structure” call, according to a statement from the Fort Worth Police Department. A neighbor told the Fort Worth Star-Telegram that he dialed a non-emergency line and requested a welfare check when he noticed that the door was ajar and the lights were on.\n\nWhile searching the outside of the house, police said, an officer saw someone standing near a window. “Perceiving a threat the officer drew his duty weapon and fired one shot striking the person inside the residence,” police said.\n\nAtatiana Jefferson, 28, was pronounced dead at the scene, according to police, who said the officers provided emergency medical care.\n\nBody-camera footage released by police Saturday shows two officers walking quietly around the side of the house and peering through two screen doors, then moving down a driveway into a backyard.\n\nOne officer approaches a closed first-floor window and shines a flashlight inside, then swiftly raises his gun. “Put your hands up! Show me your hands!” he yells. A split-second later, he fires a shot through the window. He does not identify himself as an officer in the footage.\n\nAlong with the video, police released images of a firearm officers said they found at the scene, but did not indicate whether Jefferson was holding the weapon or positioned near it when the officer opened fire. Officials did not release the officer’s name, describing him only as a white male who has been with the department since April 2018. He will be placed on administrative leave pending an investigation, according to the department.\n\nThe shooting comes at a time when relations between law enforcement and black residents in the Dallas and Fort Worth area are already under strain following the recent trial of Amber Guyger, a white former police officer who shot and killed her unarmed black neighbor, Botham Jean, in 2018.\n\nEarlier this month, following an emotionally charged courtroom saga that drew nationwide attention, a Dallas jury convicted Guyger of murder and sentenced her to 10 years in prison for killing Jean, whom she shot after mistaking his apartment for her own. Days after the sentencing, Joshua Brown, a key witness in the case, was shot and killed, stoking rumors that he was targeted because of his testimony. Police attributed Brown’s death to a drug deal gone bad and emphatically denied a connection to the Guyger case, but that has not quelled concerns from some local officials and activists, who have called for an independent investigation, as The Washington Post has reported.\n\n[The Amber Guyger case has sparked emotional fallout across Dallas]\n\nIt is not yet clear whether the officer who shot Jefferson will face criminal charges. Police said they will turn over body-camera footage and other evidence from the scene to the Tarrant County district attorney’s office, which will decide whether to prosecute.\n\nLee Merritt, a prominent civil rights attorney in the Dallas area who said he is representing Jefferson’s family, said the officer never should have opened fire. Jefferson was playing video games with her 8-year-old nephew when she heard what she thought was a prowler outside the bedroom window, Merritt wrote in a Facebook post Saturday. When Jefferson went to the window to see what was happening, he wrote, the officer shot her.\n\nMerritt described Jefferson as a “beautiful peaceful woman” who had graduated from Xavier University of Louisiana and worked in pharmaceutical equipment sales. He said her mother had recently fallen ill and that Jefferson was taking care of the house while she was in the hospital. “There was no reason for her to be murdered. None,” he said. “We must have justice.”\n ...

# %%
# Encode Data as Chars
"""
1. Create One Giant String of Articles
2. Get a list of chars
3. Get a unique list of chars
"""

giant_string = " ".join(data)

chars = list(set(giant_string))

char_int = {c:i for i,c in enumerate(chars)}
int_char = {i:c for i,c in enumerate(chars)}

# %%
indices_char = int_char
char_indices = char_int

# %%
# Create the Sequence Data

maxlen = 40
step = 5

encoded = [char_int[c] for c in giant_string]

sequences = [] # 40 characters
next_chars = [] # 1 character

for i in range(0, len(encoded) - maxlen, step):
    sequences.append(encoded[i: i + maxlen])
    next_chars.append(encoded[i + maxlen])

print('sequences: ', len(sequences))
# Out:
# sequences:  178374

# %%
# Specify x & y

X = np.zeros((len(sequences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sequences), len(chars)), dtype=np.bool)

for i, sequence in enumerate(sequences):
    for t, char in enumerate(sequence):
        X[i, t, char] = 1
        
    y[i, next_chars[i]] = 1

# %%
X[0]
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
X.shape
# Out:
# (178374, 40, 121)

# %%
X[0][0][99]
# Out:
# False

# %%
sequences[0]
# Out:
# [98,
#  29,
#  47,
#  69,
#  2,
#  1,
#  13,
#  29,
#  15,
#  37,
#  45,
#  1,
#  29,
#  103,
#  37,
#  45,
#  1,
#  69,
#  29,
#  33,
#  37,
#  54,
#  2,
#  99,
#  13,
#  29,
#  37,
#  119,
#  119,
#  2,
#  99,
#  13,
#  45,
#  29,
#  119,
#  108,
#  1,
#  108,
#  54,
#  54]

# %%
# build the model: a single LSTM
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer = optimizer)

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
text = giant_string

# %%
def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

# %%
start_index = random.randint(0, len(text) - maxlen)
sentence = text[start_index: start_index + maxlen]
generated = ''
generated += sentence

# %%
model.fit(X, y,
          batch_size=128,
          epochs=5,
          callbacks=[print_callback])
# Out:
# Train on 178374 samples
# Epoch 1/5
# 178304/178374 [============================>.] - ETA: 0s - loss: 1.7331
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "’ offense has been slowed by injuries on"
# ’ offense has been slowed by injuries on the to the call to the says that the the to the experse to the says the prosocuss a proson to the proment of the camp on the promonine and the says that a subscript of the promont and the the trade and the prosoculation of the complay and the says that the president and the said the prosoculation and the complay of the complay of the complaine and the president and the says. The the proson to the
# ----- diversity: 0.5
# ----- Generating with seed: "’ offense has been slowed by injuries on"
# ’ offense has been slowed by injuries on the monge to goad to the world all at the disclase a support a tringers and the season as the reers and the destrite a prosocul in a light that the promit of of the the this declide to the removence to the tarked to you are as a phoces share a the companse to adding the internation of the resident to the provident and a says I said that his sould to the plecter to the proson to the is a tell the
# ----- diversity: 1.0
# ----- Generating with seed: "’ offense has been slowed by injuries on"
# ’ offense has been slowed by injuries on the destritt began and what his treate annor wrepind of the lows are closerally kinding a werk of matter sobover in norther, Americs and Dodfer medezg too instacient offore as a took her musting this. : AD
#  Will This Postion to “the agott husouri spacted she against to any lawmay export your e,scunning expellty bewar of caseline Russai sofond laysual the personal insusead agree abouth spigur.
#
# Sy
# ----- diversity: 1.2
# ----- Generating with seed: "’ offense has been slowed by injuries on"
# ’ offense has been slowed by injuries on the womknveondelg. The tonk’s leike camator cerner doN he ve arrocy teysta” And preding I
#
# crejucally or lator out. (Avrienbles lowg” contain, healobaphowis . . is cityment fp, the formany pose addity: “E6len’s lu, opvonfer- e, which by colduror campaign whileing freme wait wy nextry,waturerad paetds is ande. Washingto wongehthagbaw caares dur ithe halw as a fangen wavdornames, CoJmecties, ore.
# 178374/178374 [==============================] - 111s 624us/sample - loss: 1.7331
# Epoch 2/5
# 178304/178374 [============================>.] - ETA: 0s - loss: 1.6691
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "e of the Services, and information that "
# e of the Services, and information that the president of the court to the president and the president are a mandate the court in the president and a provide to the said to the president and a mandate that the president and the president and the provide that the county and the call and a country to the president and the county and the president and the president and a subscription of the county and a provide to the president and the mand
# ----- diversity: 0.5
# ----- Generating with seed: "e of the Services, and information that "
# e of the Services, and information that use Services argued to mile the ready and more be one court to the court to its at of the than offortional and the company to have the president her a few to be not content to some in the pasturities of the struck to the Services of the post long to the partifle to server to this fearn of recairs entired to a the president is the United States have be days that a don’t he play.
#
# Oty a more that th
# ----- diversity: 1.0
# ----- Generating with seed: "e of the Services, and information that "
# e of the Services, and information that the clicks in yenres Haroe Schiff offending his impeachment next werk
#
# (In hm1U, out a veria has luse horift in Swassings 1:
#
# his husere cadforted is surpertiofal cated bu his Starrgory pilst
#
# Trump, hip you racks. As Times Some was Trump connerning “adgents of Chint, Rac, rarmina decrousing the — a, huselly at Henduney Collonst on polit with vousevery from Williin and Acore Trump’s other investi
# ----- diversity: 1.2
# ----- Generating with seed: "e of the Services, and information that "
# e of the Services, and information that make hildillstals, his less Houppohp.
#
# Ko.”
#
# Mleusbar. Jovid (juffailM3).) lever uncusing her-a suary-includy ploacher eamfert. we planore larges a.clus, Yo9” Trump his smary cliaso.
#
# The bliEm.”
#
# ADb” an aurling money propered te ren and an of examin xiforing replectAy reprowined,” Permy, Sunday sayidet. the Can dessival PoopSer authorigated uspenitions Dover. Inacy.
#
# Coarchs)over more command, H
# 178374/178374 [==============================] - 110s 617us/sample - loss: 1.6692
# Epoch 3/5
# 178176/178374 [============================>.] - ETA: 0s - loss: 1.6256
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "e reconstitution of the Islamic State,” "
# e reconstitution of the Islamic State,” and the Services that the president and the president with the president and a surprose and the president and the first the president to the transcription and a good to make the congressive to she was and any president and the president and the president to conservative to provide the president and a discreting to she was the and a surprosents and an advertising the president and the party and the
# ----- diversity: 0.5
# ----- Generating with seed: "e reconstitution of the Islamic State,” "
# e reconstitution of the Islamic State,” she was the month the partic to be an called and the American indught to was to provessions to best for her much most and active the proside of the a subscription to provide his second and about the protecting a trought the one was one a simmar and her transcription being conservative continued to a instration on the strattion, and home. I mong not to a statement to a conver from streation has sur
# ----- diversity: 1.0
# ----- Generating with seed: "e reconstitution of the Islamic State,” "
# e reconstitution of the Islamic State,” nobed smart. Acadley, open instead of a full works to hin reable head to nectities. He (assoved concern to won’t bother and servaking that a  I like inctoate end undersens to plated play, handing hande, the fame thius the as works. with the “in care
#
# Dis driting, wereing 20 be from the jo man at Jare and respensive the end of kind and any Coepress, wores” on the us plece at Colkrani bue  and the c
# ----- diversity: 1.2
# ----- Generating with seed: "e reconstitution of the Islamic State,” "
# e reconstitution of the Islamic State,” Flohar.
#
# Wride beher to ” e.n, pertere:
#
# Almash revery La2’s tlee troubld.”
#
# I suves,” S4urving migrks, Pardies 199 to No. LaL) regime his great the Skrarand, told a user)
#
# Ix Cplosfigle Sreat inserain Imwaissirt skee. The pash this telabe, works,’ Cama wart, largnina’s medicative omed new in Jef, Loims Mmis brah fourt a/ a-approal formed a condom, Cuplia-weeopps in NutT4HE EER ENTECORRIA)
#
# Tz“JC“
# 178374/178374 [==============================] - 112s 630us/sample - loss: 1.6256
# Epoch 4/5
# 178304/178374 [============================>.] - ETA: 0s - loss: 1.5951
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "vies such as “The Black Hole” (1979), “A"
# vies such as “The Black Hole” (1979), “All and Alers was the wash the company to the trans and the country to the said of the released the country of the and the was the control of the content of the promis that they are and other with the company to the country and the country said the end the country to the company to the end the problems with the trans and the country and a standing the country and the promis to the and the forder th
# ----- diversity: 0.5
# ----- Generating with seed: "vies such as “The Black Hole” (1979), “A"
# vies such as “The Black Hole” (1979), “All in of “Service where the were to the was price to a really to the interview resign to time, a can corminist the wates who could be the country with the Califis Joh Warding writte with the said the our promiting and while his out of the bests the world and and consignate to the new to the country to the new sers and the unduring it are and that they are out from reasonable for the released they
# ----- diversity: 1.0
# ----- Generating with seed: "vies such as “The Black Hole” (1979), “A"
# vies such as “The Black Hole” (1979), “A cally stoting it rasted ball of will tented unon Infloment and child grepted it hep by intendant Trum viof Tp. Trump as falls.
#
# but and which is bio spent or Vilobpan mash bag. Minild Tauday WNlew In moundause from washington, and tracked appirated about strips. D, Wook Wet’s : Johan Steps’s a teep Parted or Fave Servieteur, sick night to unfilm, thin were into collouse to and thene so view the p
# ----- diversity: 1.2
# ----- Generating with seed: "vies such as “The Black Hole” (1979), “A"
# vies such as “The Black Hole” (1979), “Arn in howar Avewi, is ruits hit a. With Mathinia Ally, a cerrer.
#
# theye IraG lodg, it country constitates usert (often’s’ Ause Schificoom. Evidetwe froarones have twingster, Chri2l weok lates.
#
# PExmorffo-geeraine and sonk and polling Anna with mile opplecably loanch2. Cosh and.
#
# Hroweroning and owrecocinH and eDennep impostime, campaignes it. The Washington tcake was geSteelign,” moyen” tratecred
# 178374/178374 [==============================] - 112s 630us/sample - loss: 1.5953
# Epoch 5/5
# 178176/178374 [============================>.] - ETA: 0s - loss: 1.5732
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "nse Secretary Mark T. Esper on Sunday.
#
# "
# nse Secretary Mark T. Esper on Sunday.
#
# “I sund and a statement to the company of the company to a month with the company that the second the started the statement the company a provide the company of the company a statement to the provide in the real the president in the company and the company and the company of the company of the company of the company a manned and a month the company and the company that the company a lite in the co
# ----- diversity: 0.5
# ----- Generating with seed: "nse Secretary Mark T. Esper on Sunday.
#
# "
# nse Secretary Mark T. Esper on Sunday.
#
# AD
#
# “It and the deal the reection is the potently, he deportic commany in political and sundakes and the company in the Services company and critical or enoughters and effective much work for forces of the contextical company to supponsience leader in the pulling she as a provide with the Services and I still make in one and spot the real by the posture is the some policy in the president him of t
# ----- diversity: 1.0
# ----- Generating with seed: "nse Secretary Mark T. Esper on Sunday.
#
# "
# nse Secretary Mark T. Esper on Sunday.
#
# AD
#  Jarvines.
#
# Comber dride forces, sundo why came in they vaned this Deside, hend amountersmently dayn, and
#
# 20 mall :Senation, fut a fere the Daves.
#
# Reforess to month,” News sounces to descring play avere our community a stabedogr and her visit. They medrof ou in a gaust portic with 1bits. You,v: Acrovers, goneth of to fougn1 for Sunday bed insteaded to dilly from youm-l. Cister, Trump border
# ----- diversity: 1.2
# ----- Generating with seed: "nse Secretary Mark T. Esper on Sunday.
#
# "
# nse Secretary Mark T. Esper on Sunday.
#
# Tuen. Min side. At little,-astymattly, and modeln Roddy ord except. expleteself after a gented. and artamabager out. Yov afh. hour recovtred your insime blacket’s rrablic sending. On-Tue.TPF. Whinee Others government mesticel “itKled, the plunnking firing the cheichmer would Rosom time clite concerned to get-viding 25 yearr cordirgs.
#
# AD
#
# To, the rightnyilf and callet flove to 20 sicue to rimild S
# 178374/178374 [==============================] - 112s 628us/sample - loss: 1.5732
